# %%
import pandas as pd

# %%
df_2017=pd.read_csv("Sales Transactions-2017.csv")

# %%
df_2018=pd.read_csv("Sales Transactions-2018.csv")

# %%
df_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
filter_2017=df_2017[["Voucher","Party","Product"]]
filter_2017
# Out:
#          Voucher               Party            Product
# 0          Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1          Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2          Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3          Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4          Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...          ...                 ...                ...
# 47285  Sal:10042                 Vkp        10*10 SHEET
# 47286        NaN                 NaN                NaN
# 47287        NaN                 NaN                NaN
# 47288    Total                   NaN                NaN
# 47289    Total                   NaN                NaN
#
# [47290 rows x 3 columns]

# %%
df_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
filter_2018=df_2018[["Party","Product","Qty"]]

# %%
filter_2017
# Out:
#          Voucher               Party            Product
# 0          Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1          Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2          Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3          Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4          Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...          ...                 ...                ...
# 47285  Sal:10042                 Vkp        10*10 SHEET
# 47286        NaN                 NaN                NaN
# 47287        NaN                 NaN                NaN
# 47288    Total                   NaN                NaN
# 47289    Total                   NaN                NaN
#
# [47290 rows x 3 columns]

# %%
filter_2018
# Out:
#              Party            Product           Qty
# 0             TP13  SILVER POUCH 9*12            50
# 1             TP13             RUBBER             5
# 2             TP13   DURGA 10*12 Blue      1,600.00
# 3             TP13   DURGA 13*16 BLUE           400
# 4             TP13    10*12 SARAS-NAT           600
# ...            ...                ...           ...
# 44735  HAMPI FOODS        SPOON SOOFY           200
# 44736          NaN                NaN           NaN
# 44737          NaN                NaN           NaN
# 44738          NaN                NaN    666,056.00
# 44739          NaN                NaN  7,097,803.00
#
# [44740 rows x 3 columns]

# %% [markdown]
# ## Inner join

# %%
# default the python takes inner join
'''
party and product are the two columns that are common in the two join so it took it and all the values which common in both the table
matched items are printed
'''
# Out:
# '\nparty and product are the two columns that are common in the two join so it took it and all the values which common in both the table\nmatched items are printed\n'

# %%
filter_2017.merge(filter_2018)
# Out:
#          Voucher             Party        Product           Qty
# 0          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             5
# 1          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# 2          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# 3          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             8
# 4          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# ...          ...               ...            ...           ...
# 1393140  Total                 NaN            NaN    490,737.40
# 1393141  Total                 NaN            NaN           NaN
# 1393142  Total                 NaN            NaN           NaN
# 1393143  Total                 NaN            NaN    666,056.00
# 1393144  Total                 NaN            NaN  7,097,803.00
#
# [1393145 rows x 4 columns]

# %%
#when the basis is changed only on the party it divided the product

# %%
filter_2017.merge(filter_2018,on="Party")
# Out:
#           Voucher             Party      Product_x        Product_y  \
# 0           Sal:1  SOLANKI PLASTICS  DONA-VAI-9100  LITE FOAM(1200)
# 1           Sal:1  SOLANKI PLASTICS  DONA-VAI-9100       DONA-(108)
# 2           Sal:1  SOLANKI PLASTICS  DONA-VAI-9100    DONA-VAI-9100
# 3           Sal:1  SOLANKI PLASTICS  DONA-VAI-9100  LITE FOAM(1200)
# 4           Sal:1  SOLANKI PLASTICS  DONA-VAI-9100       DONA-(108)
# ...           ...               ...            ...              ...
# 39414195  Total                 NaN            NaN              NaN
# 39414196  Total                 NaN            NaN              NaN
# 39414197  Total                 NaN            NaN              NaN
# 39414198  Total                 NaN            NaN              NaN
# 39414199  Total                 NaN            NaN              NaN
#
#                    Qty
# 0                    3
# 1                    2
# 2                    5
# 3                    4
# 4                    5
# ...

# %% [markdown]
# ## outer join

# %%
'''
outer join combines whole dataframe and combines into one  on the basis of part and product so when there no similar values
it gives NaN'''
# Out:
# '\nouter join combines whole dataframe and combines into one  on the basis of part and product so when there no similar values\nit gives NaN'

# %%
filter_2017.merge(filter_2018,how="outer")
# Out:
#          Voucher                Party Product           Qty
# 0            NaN   6-120 ki amount 42
# 1            NaN                BANK)     NaN           NaN
# 2            NaN                BANK)     NaN           NaN
# 3            NaN                BANK)     NaN           NaN
# 4            NaN                BANK)     NaN           NaN
# ...          ...                  ...     ...           ...
# 1415333  Total                    NaN     NaN    490,737.40
# 1415334  Total                    NaN     NaN           NaN
# 1415335  Total                    NaN     NaN           NaN
# 1415336  Total                    NaN     NaN    666,056.00
# 1415337  Total                    NaN     NaN  7,097,803.00
#
# [1415338 rows x 4 columns]

# %%
# left  join

# %%
filter_2017.merge(filter_2018,how="left")
# Out:
#          Voucher             Party        Product           Qty
# 0          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             5
# 1          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# 2          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# 3          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             8
# 4          Sal:1  SOLANKI PLASTICS  DONA-VAI-9100             6
# ...          ...               ...            ...           ...
# 1404471  Total                 NaN            NaN    490,737.40
# 1404472  Total                 NaN            NaN           NaN
# 1404473  Total                 NaN            NaN           NaN
# 1404474  Total                 NaN            NaN    666,056.00
# 1404475  Total                 NaN            NaN  7,097,803.00
#
# [1404476 rows x 4 columns]

# %%
# right join

# %%
filter_2017.merge(filter_2018,how="right")
# Out:
#           Voucher Party            Product           Qty
# 0         Sal:552  TP13  SILVER POUCH 9*12            50
# 1         Sal:884  TP13  SILVER POUCH 9*12            50
# 2        Sal:1443  TP13  SILVER POUCH 9*12            50
# 3        Sal:1867  TP13  SILVER POUCH 9*12            50
# 4        Sal:2344  TP13  SILVER POUCH 9*12            50
# ...           ...   ...                ...           ...
# 1404002   Total     NaN                NaN  7,097,803.00
# 1404003       NaN   NaN                NaN  7,097,803.00
# 1404004       NaN   NaN                NaN  7,097,803.00
# 1404005   Total     NaN                NaN  7,097,803.00
# 1404006   Total     NaN                NaN  7,097,803.00
#
# [1404007 rows x 4 columns]

# %% [markdown]
# # groupby

# %%
df=pd.read_csv("Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df_groupby_frame = df.groupby("Base Flavor")

# %%
df_groupby_frame.mean(numeric_only = True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df_groupby_frame.count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df_groupby_frame.min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df_groupby_frame.max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby("Base Flavor").agg({"Flavor Rating":["mean","min","max","count","std"],"Texture Rating":["mean","min","max","count","std"]})
# Out:
#             Flavor Rating                            Texture Rating            \
#                      mean  min   max count       std           mean  min  max
# Base Flavor
# Chocolate             8.4  8.2   8.8     3  0.346410       7.233333  7.0  7.6
# Vanilla               5.7  2.3  10.0     6  2.710719       5.650000  3.4  8.0
#
#
#             count       std
# Base Flavor
# Chocolate       3  0.321455
# Vanilla         6  1.566844

# %%
df.groupby(["Base Flavor","Liked"]).agg({"Flavor Rating":["mean","min","max","count","std"],"Texture Rating":["mean","min","max","count","std"]})
# Out:
#                   Flavor Rating                            Texture Rating  \
#                            mean  min   max count       std           mean
# Base Flavor Liked
# Chocolate   Yes             8.4  8.2   8.8     3  0.346410       7.233333
# Vanilla     No              3.6  2.3   4.7     3  1.212436       4.466667
#             Yes             7.8  6.5  10.0     3  1.915724       6.833333
#
#
#                    min  max count       std
# Base Flavor Liked
# Chocolate   Yes    7.0  7.6     3  0.321455
# Vanilla     No     3.4  5.0     3  0.923760
#             Yes    6.0  8.0     3  1.040833
